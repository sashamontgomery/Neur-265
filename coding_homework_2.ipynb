# %% [markdown]
# <a href="https://colab.research.google.com/github/sashamontgomery/Neur-265/blob/main/coding_homework_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Sasha Montgomery
# <i> NEUR 265: Intro to Neural Data Analysis <i>
#
# <b> February 19th, 2026 <b>

# %%
#importing numpy, plt, and statistics
import numpy as np
import matplotlib.pyplot as plt
import statistics as st

# %%
#Importing data (v_rest_sst and v_rest_pvalb) as numpy arrays
##importing sst data and setting to v_rest1 variable
sst_url = 'https://raw.githubusercontent.com/hallockh/neur_265_spring2026/refs/heads/main/data/v_rest_sst.csv'
v_rest1 = np.loadtxt(sst_url)
##importing pvalb data and setting to v_rest2 variable
pvalb_url = sst_url = 'https://raw.githubusercontent.com/hallockh/neur_265_spring2026/refs/heads/main/data/v_rest_pvalb.csv'
v_rest2 = np.loadtxt(pvalb_url)

# %%
#concatenate v_rest_sst and v_rest_pvalb into a matrix
row1 = np.array(v_rest1)
row2 = np.array(v_rest2)
v_rest = np.vstack ((row1,row2))
#checking v_rest matrix shape
print(v_rest.shape)
# Out:
# (2, 500)

# %%
#size of v_rest matrix
print(v_rest.size)
# Out:
# 1000

# %%
#printing first row of v_rest
print(v_rest[0])
# Out:
# [-68.24292501 -69.60158234 -76.03420105 -71.16118393 -76.35402679
#  -70.89105013 -64.11880341 -72.8632112  -78.96890068 -55.4531032
#  -60.98506045 -66.61118807 -67.08294233 -73.90523593 -74.63317594
#  -49.27067811 -76.05053997 -65.45417595 -58.53314018 -66.28985665
#  -64.09106996 -71.49303228 -65.11718958 -73.74140637 -74.81462097
#  -71.32343356 -74.46990373 -65.03939126 -71.94757271 -73.42034054
#  -71.10602856 -61.28795481 -73.79654069 -64.48533249 -69.65824959
#  -73.71225967 -85.56860669 -57.49219704 -76.91730436 -62.61127641
#  -67.08071963 -78.45983535 -78.87342682 -76.14055703 -62.40101166
#  -72.41336346 -62.03701146 -63.30990855 -62.02654052 -73.0206111
#  -63.11713295 -70.05060087 -75.7537974  -57.15310111 -72.52368011
#  -70.86691952 -65.435009   -66.87690226 -70.79107895 -71.34088898
#  -65.70912288 -64.45794886 -62.82061958 -65.03326961 -61.37704976
#  -71.51313705 -71.54903143 -83.53790652 -68.49228492 -69.6041454
# ...

# %%
#checking if returning correct # of items in first row of v_rest
v_rest_check = (v_rest[0])
print(v_rest_check.size)
# Out:
# 500

# %%
#finding sum of third column of v_rest
v_rest[:,2].sum()
# Out:
# np.float64(-151.75359464)

# %%
#print second to last value in second row of v_rest
v_rest[1, -2]
# Out:
# np.float64(-49.80412917)

# %%
#create histogram of first row of values of v_rest
plt.hist(v_rest[0])

#label axes
plt.ylabel('Counts')
plt.xlabel('Interspike Interval (millisecond))')
# Out:
# Text(0.5, 0, 'Interspike Interval (millisecond))')

# %%
#mean of first row of v_rest
v_rest_mean_sst = st.mean(v_rest[0])
print(v_rest_mean_sst)

#mean of second row of v_rest
v_rest_mean_pvalb = st.mean(v_rest[1])
print(v_rest_mean_pvalb)
# Out:
# -67.73465864056
# -69.97869017908

# %% [markdown]
# The means of the sst row is bigger than the mean of the second row, the pvalb row.

# %%
#import scipy.stats
import scipy.stats as stats

# %%
#t-test on two rows of v_rest
stats.ttest_ind(v_rest[0],v_rest[1])
# Out:
# TtestResult(statistic=np.float64(5.837507010328816), pvalue=np.float64(7.159828660199036e-09), df=np.float64(998.0))

# %% [markdown]
# The p-value is much smaller than 0.05 (p = 7.159828660199036e-09), so there is a statistically significant difference between the two rows, and therefore between the sst and the pvalb means.
