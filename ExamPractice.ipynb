# %% [markdown]
# <a href="https://colab.research.google.com/github/sashamontgomery/Neur-265/blob/main/ExamPractice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Sasha Montgomery
# <i>NEUR 265<i>
#
# <b> March 9,2026<b>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

url1 = 'https://raw.githubusercontent.com/hallockh/neur_265_spring2026/refs/heads/main/data/v_rest_sst.csv'
pandas_data1 = pd.read_csv(url1)

url2 = 'https://raw.githubusercontent.com/hallockh/neur_265_spring2026/refs/heads/main/data/v_rest_pvalb.csv'

pandas_data2 = pd.read_csv(url2)

# %% [markdown]
# convert pandas data1 into a list variable

# %%
data1 = pandas_data1.values.tolist()
data2 = pandas_data2.values.tolist()

# %% [markdown]
# prevent bracketing each individual element so flaten data1 and data2 by using numpy.squeeze

# %%
data1 = np.squeeze(data1)
data2 = np.squeeze(data2)

# %%
#prints length
len(data1)
# Out:
# 499

# %%
#printing 3rd,4th, 5th,6th elements of data2
data2[2:6]
# Out:
# array([-72.36807022, -63.09300825, -75.5469301 , -66.51929994])

# %%
#second to last and last elements
data1[-3:-1]
# Out:
# array([-69.71809673, -65.59535842])

# %%
#find type of data
type(data2)
# Out:
# numpy.ndarray

# %%
#making histograms
plt.hist(data1)
plt.xlabel('ISI (milliseconds)')
plt.ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')

# %%
#making data2 histogram
plt.hist(data2)
plt.xlabel('ISI (milliseconds)')
plt.ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')

# %% [markdown]
# Data2 (the Pvalb data) seems to have a lower resting membrane potential compared to data1 (the SST data). The interspike interval time (ISI) of data1 appears faster compared to the histogram showing the ISI of data2. A shorter ISI suggests that the resting membrane potential is closer to the threshold for an action potential, because less time is needed between action potentials, and thus shorter ISI.

# %%
#making data3 variable
data3 = [data1,data2]

# %%
#print last element of data2
print(data3[1][-1])
# Out:
# -54.08427915

# %% [markdown]
# Coding Homework 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import statistics as st

# %%
#import using numpy
url3 = 'https://raw.githubusercontent.com/hallockh/neur_265_spring2026/refs/heads/main/data/v_rest_sst.csv'
v_rest1 = np.loadtxt(url3)
url4 = 'https://raw.githubusercontent.com/hallockh/neur_265_spring2026/refs/heads/main/data/v_rest_pvalb.csv'
v_rest2 = np.loadtxt(url4)

# %%
#Concatenate into v_rest matrix
row1 = np.array(v_rest1)
row2 = np.array(v_rest2)

v_rest = np.vstack((row1,row2))
#OR

v_rest2 = np.vstack((v_rest1,v_rest2))

# %%
#printing shape and size
print(v_rest.shape)
print(v_rest.size)

print(v_rest2.shape)
print(v_rest2.size)
# Out:
# (2, 500)
# 1000
# (2, 500)
# 1000

# %%
#printing first row of v_rest
v_rest[0]
# Out:
# array([-68.24292501, -69.60158234, -76.03420105, -71.16118393,
#        -76.35402679, -70.89105013, -64.11880341, -72.8632112 ,
#        -78.96890068, -55.4531032 , -60.98506045, -66.61118807,
#        -67.08294233, -73.90523593, -74.63317594, -49.27067811,
#        -76.05053997, -65.45417595, -58.53314018, -66.28985665,
#        -64.09106996, -71.49303228, -65.11718958, -73.74140637,
#        -74.81462097, -71.32343356, -74.46990373, -65.03939126,
#        -71.94757271, -73.42034054, -71.10602856, -61.28795481,
#        -73.79654069, -64.48533249, -69.65824959, -73.71225967,
#        -85.56860669, -57.49219704, -76.91730436, -62.61127641,
#        -67.08071963, -78.45983535, -78.87342682, -76.14055703,
#        -62.40101166, -72.41336346, -62.03701146, -63.30990855,
#        -62.02654052, -73.0206111 , -63.11713295, -70.05060087,
#        -75.7537974 , -57.15310111, -72.52368011, -70.86691952,
#        -65.435009  , -66.87690226, -70.79107895, -71.34088898,
# ...

# %%
#printing sum of values in third colum of vrest
v_rest[:,2].sum()
# Out:
# np.float64(-151.75359464)

# %%
#second to last value in second row of v_rest
print(v_rest[1,-2])
# Out:
# -49.80412917

# %%
#making hisotrgram of values in first row of v_rest
plt.hist(v_rest[0])
plt.xlabel('ISI(milliseconds)')
plt.ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')

# %%
#mean of first row and assigns meanto varaible
#mean funcion is st.mean()
v_rest_mean_sst = st.mean(v_rest[0])
print(v_rest_mean_sst)

v_rest_mean_pvalb = st.mean(v_rest[1])
print(v_rest_mean_pvalb)
# Out:
# -67.73465864056
# -69.97869017908

# %%
import scipy.stats as stats

# %%
#t.test on two rows of v_rest
stats.ttest_ind(v_rest[0],v_rest[1])
# Out:
# TtestResult(statistic=np.float64(5.837507010328816), pvalue=np.float64(7.159828660199036e-09), df=np.float64(998.0))

# %% [markdown]
# Coding Homework 3

# %%
url5 = 'https://raw.githubusercontent.com/hallockh/neur_265_spring2026/refs/heads/main/data/v_rest_sst.csv'
v_rest_sst = np.loadtxt(url5)
url6 = 'https://raw.githubusercontent.com/hallockh/neur_265_spring2026/refs/heads/main/data/v_rest_pvalb.csv'
v_rest_pvalb = np.loadtxt(url6)

# %%
#find means
st.mean(v_rest_sst)
st.mean(v_rest_pvalb)
# Out:
# np.float64(-69.97869017908)

# %%
#t.test
t_stats, p_value = stats.ttest_ind(v_rest_sst,v_rest_pvalb)
print(t_stats)
print(p_value)
# Out:
# 5.837507010328816
# 7.159828660199036e-09

# %%
if p_value <0.05:
  fig, ax = plt.subplots(1,2)
  ax[0].hist(v_rest_sst)
  ax[0].set_title("v_rest_sst")
  ax[0].set_xlabel("ISI")
  ax[0].set_ylabel("Count")
  ax[1].hist(v_rest_pvalb)
  ax[1].set_title("v_rest_pvalb")
  ax[1].set_xlabel("ISI")
  ax[1].set_ylabel("Count")

# %%
def vrestHist():
  if p_value <0.05:
    fig, ax = plt.subplots(1,2)
    ax[0].hist(v_rest_sst)
    ax[0].set_title("v_rest_sst")
    ax[0].set_xlabel("ISI")
    ax[0].set_ylabel("Count")
    ax[1].hist(v_rest_pvalb)
    ax[1].set_title("v_rest_pvalb")
    ax[1].set_xlabel("ISI")
    ax[1].set_ylabel("Count")

# %%
vrestHist()

# %%
#loops columns of v_rest_sst and v_rest_pvalb
sst_length = len(v_rest_sst)
for i in range(sst_length):
  if v_rest_sst[i] < -60 and v_rest_pvalb[i] > -60:
    plt.scatter(v_rest_sst[i],v_rest_pvalb[i],color = "purple")
  elif v_rest_sst[i] > -60 and v_rest_pvalb[i] > -60:
    plt.scatter(v_rest_sst[i],v_rest_pvalb[i],color = "red")
  elif v_rest_sst[i] < -60 and v_rest_pvalb[i] < -60:
    plt.scatter(v_rest_sst[i],v_rest_pvalb[i],color = "blue")
  elif v_rest_sst[i] > -60 and v_rest_pvalb[i] < -60:
    plt.scatter(v_rest_sst[i],v_rest_pvalb[i],color = "green")
#labeling axes
plt.xlabel("Sst")
plt.ylabel("Pvalb")
# Out:
# Text(0, 0.5, 'Pvalb')

# %% [markdown]
# Coding Homework 4

# %%
#import patch seq data

url9 = 'https://raw.githubusercontent.com/hallockh/neur_265_spring2026/refs/heads/main/data/patch_seq_expanded.csv'


patch_seq = pd.read_csv(url9)

# %%
#plot patch seq as bar graph
patch_seq['Marker'].value_counts().plot(kind = 'bar')
plt.xlabel('Marker')
plt.ylabel('Value Counts/# of Observations')
# Out:
# Text(0, 0.5, 'Value Counts/# of Observations')

# %%
#plot patch seq as pie chart
#plot patch seq
patch_seq['Marker'].value_counts().plot(kind = 'pie')
plt.xlabel('Marker')
plt.ylabel('Value Counts/# of Observations')
# Out:
# Text(0, 0.5, 'Value Counts/# of Observations')

# %%
#Making scatterplot with for loop
patch_length = len(patch_seq)
for i in range(patch_length):
    x = patch_seq['ISI'].iloc[i]
    y = patch_seq['Fast_Trough'].iloc[i]
    marker = patch_seq['Marker'].iloc[i]
    if marker == 'Sst':
        plt.scatter(x, y, color='Red')
    if marker == 'Pvalb':
        plt.scatter(x, y, color='Blue')
plt.ylabel('Fast Trough')
plt.xlabel('ISI')
# Out:
# Text(0.5, 0, 'ISI')

# %%
#defining a function for patchscatter
def patchScatter():
    patch_length = len(patch_seq)
    for i in range(patch_length):
      x = patch_seq['ISI'].iloc[i]
      y = patch_seq['Fast_Trough'].iloc[i]
      marker = patch_seq['Marker'].iloc[i]
      if marker == 'Sst':
          plt.scatter(x, y, color='Red')
      if marker == 'Pvalb':
          plt.scatter(x, y, color='Blue')
      plt.ylabel('Fast Trough')
      plt.xlabel('ISI')

# %%
#checking patchscatter works right
patchScatter()

# %%
#getting mean sd and range
patch_seq.groupby('Marker')['Fast_Trough'].describe()

# %% [markdown]
# The "Sst" neurons have a greater mean than the "Pvalb" neurons. This suggests that the Pvalb neuron group has a more negative undershoot following an action potential.

# %%
#checking fast trough skew
patch_seq.groupby('Marker')['Fast_Trough'].skew()
# Out:
# Marker
# Pvalb    0.19536
# Sst      0.00125
# Name: Fast_Trough, dtype: float64

# %% [markdown]
# The Pvalb neurons have a skewed distribution, while the Sst neurons do not have a skewed distribution.

# %%
#checking ISI skew
patch_seq.groupby('Marker')['ISI'].skew()

# %% [markdown]
# Both the Sst and the Pvalb neurons have a skewed distribution.

# %%
#t test with fast trough
sst_neurons = patch_seq [patch_seq['Marker']== 'Sst']
pvalb_neurons = patch_seq [patch_seq['Marker']== 'Pvalb']
stats.ttest_ind (sst_neurons['Fast_Trough'], pvalb_neurons['Fast_Trough'])

# %% [markdown]
# The undershoot voltage significantly differs between the two groups. I know this because the p value is <0.05

# %%
 #t test with ISI
sst_neurons = patch_seq [patch_seq['Marker']== 'Sst']
pvalb_neurons = patch_seq [patch_seq['Marker']== 'Pvalb']
sst1 = sst_neurons['ISI'].dropna()
pvalb1 = pvalb_neurons['ISI'].dropna()
stats.ttest_ind(sst1, pvalb1)
# Out:
# TtestResult(statistic=np.float64(14.643966775010774), pvalue=np.float64(2.694292788633572e-38), df=np.float64(354.0))

# %% [markdown]
# The undershoot voltage does not differ significantly between the two ISI groups. I know this because the p value is greater that .05.
